# %% [markdown]
# QUESTÃO 1: Crie um programa que leia seu nome completo e mostre:
# • Seu nome com todas as letras maiúsculas;
# • Seu nome com todas as letras minúsculas;
# • Quantas letras ao todo tem seu nome;
# • E como seria se trocássemos seu último nome para “do Inatel”.

# %%
nome = str(input("Digite seu nome:"))
uprNome = nome.upper()
mnNome = nome.lower()
lenNome = len(nome)
splitName = nome.split()

if len(splitName) > 1:
  splitName[-1] = "do Inatel"
  newName = " ".join(splitName)
else:
  splitName += "do Inatel"

print(uprNome)
print(mnNome)
print(lenNome)
print(newName)
# Out:
# Digite seu nome:joao victor
# JOAO VICTOR
# joao victor
# 11
# joao do Inatel

# %% [markdown]
# QUESTÃO 2: Mostre a tabuada de um número que o usuário escolher dentro de um intervalo
# específico também escolhido por ele.

# %%
num = int(input("Digite seu numero inteiro"))

lowerLimit = int(input("digite o inicio do intervalo da tabuada"))
upperLimit = int(input("digite o fim do intervalo da tabuada"))

for i in range(lowerLimit, upperLimit + 1):
  print(f"{num} x {i} = {num * i}")
# Out:
# Digite seu numero inteiro10
# digite o inicio do intervalo da tabuada1
# digite o fim do intervalo da tabuada10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# QUESTÃO 3: Faça um programa que leia o sexo de uma pessoa e diga se ela é homem (caso seja
# digitado M) ou mulher (caso seja digitado F). Caso seja digitado algo inválido, continue
# perguntando até que o usuário entre com um sexo válido.

# %%
sexo = input("digite o sexo")

while(sexo != "M" and sexo != "F"):
  sexo = input("digite o sexo")

if sexo == "M":
  print("Homem")
else:
  print("Mulher")

# %% [markdown]
# QUESTÃO 4: Desenvolva um script que pergunte a distância de uma viagem em Km. Calcule o
# preço da passagem, cobrando R$0.50 por Km para viagens até 200Km e R$0.45 para viagens
# mais longas

# %%
distancia = float(input("Digite a distancia em km"))

if distancia <= 200:
  print(f"O preço da passagem é de R${distancia * 0.5}")
else:
  print(f"O preço da passagem é de R${distancia * 0.45}")
# Out:
# Digite a distancia em km100
# O preço da passagem é de R$50.0

# %% [markdown]
# QUESTÃO 5: Faça um programa que leia um número entre 1000 e 9999 e mostre na tela:
# • Qual o número da unidade;
# • Número da dezena;
# • Número da centena;
# • E número do milhar.

# %%
x = 0

while x < 1000 or x > 9999:
  x = int(input("Digite um numero entre 1000 e 9999"))

unidade = x % 10
dezena = (x // 10) % 10
centena = (x // 100) % 10
milhar = (x // 1000) % 10

print(unidade)
print(dezena)
print(centena)
print(milhar)
# Out:
# Digite um numero entre 1000 e 99991234
# 4
# 3
# 2
# 1

# %% [markdown]
# QUESTÃO 6: Peça ao usuário para entrar com um número decimal. Em seguida, aplique e mostre
# o resultado:
# • Da raiz quadrada deste número;
# • Função teto;
# • Função chão;
# • Sua parte inteira.

# %%
import math

num = float(input("input float number"))

sqr = math.sqrt(num)
floor = math.floor(num)
ceil = math.ceil(num)
trunc = math.trunc(num)

print(sqr)
print(floor)
print(ceil)
print(trunc)
# Out:
# input float number10.1341234
# 3.183413796539809
# 10
# 11
# 10

# %% [markdown]
# QUESTÃO 7: Faça um programa que leia uma palavra. Esse programa deve percorrer a palavra e
# imprimir cada letra em maiúsculo, uma letra por linha. Ao final, deverá informar quantas vogais
# a palavra tem e se a letra “a” está presente nela.

# %%
import re

palavra = input("Digite uma palavra")
vogais = 0

for letra in palavra:
    print(letra.upper())


vogais_encontradas = re.findall(r'[aeiou]', palavra.lower())
has_a = bool(re.search(r'[a]', palavra.lower()))
qtd_vogais = len(vogais_encontradas)

print(qtd_vogais)
print(has_a)
# Out:
# Digite uma palavrajoao
# J
# O
# A
# O
# 3
# True

# %% [markdown]
# QUESTÃO 8: Crie um programa que leia dois números calculando as operações abaixo. Em
# seguida, informe ao final das operações se o resultado da adição é par ou ímpar:
# • Adição
# • Subtração
# • Multiplicação
# • Divisão
# • Resto da divisão
# • Potência, o primeiro número elevado ao segundo

# %%
x = int(input("Digite o primeiro numero"))
y = int(input("Digite o segundo numero"))

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
# Out:
# Digite o primeiro numero5
# Digite o segundo numero5
# 10
# 0
# 25
# 1.0
# 0
# 3125
